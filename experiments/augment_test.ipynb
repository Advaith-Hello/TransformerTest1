# %%
import jax.numpy as jnp
import jax.random as jrd

import matplotlib.pyplot as plt

from my_project import get_data
from my_project import augment

from my_project.samples import sample_augments

# %%
(train_x, train_y), (test_x, test_y) = get_data.get_data(
    batch_size=256,
    dataset="fashion_mnist",
    max_per_split=[60_000, 10_000]
)
# Out:
# C:\Users\advai\PycharmProjects\TransformerTest1\.venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
augmented_example = augment.augment(train_x[100], jrd.PRNGKey(0), sample_augments.augments2)
plt.imshow(augmented_example[0][0], cmap='gray')
plt.show()
